# %% [markdown]
# # Цикл `for` в Python
#
# Учебник для ученицы, которая знает `print()`, `input()`, `int()`, переменные, математические операции и `if / elif / else`. Новая конструкция — `range()`. Здесь не нужны списки, функции, методы строк, `while`, `break`, `continue` и `enumerate`.
#
# Запускай ячейки сочетанием Shift+Enter и меняй числа в примерах.

# %% [markdown]
# ## 1. Зачем нужны циклы
#
# Цикл нужен, когда одну и ту же команду надо выполнить много раз. Вместо повторения одинаковых строк мы описываем действие один раз и говорим Python, сколько раз его повторить.

# %%
print("Привет!")
print("Привет!")
print("Привет!")

# %% [markdown]
# ## 2. Синтаксис `for`
#
# Общий вид:
# ```python
# for переменная in range(количество):
#     команда
# ```
#
# `for` начинает цикл, переменная получает очередное число, после `range(...)` ставится двоеточие, а команды внутри цикла имеют одинаковый отступ (обычно 4 пробела). Отступ показывает Python, какие команды относятся к циклу.

# %%
for i in range(5):
    print("Повторение номер", i)

# %% [markdown]
# ## 3. `range()` и правая граница
#
# `range(N)` даёт числа от 0 до `N - 1`. Поэтому `range(5)` даёт 0, 1, 2, 3, 4 — всего пять чисел. Правая граница не включается.
#
# `range(start, stop)` начинается с `start` и идёт до числа перед `stop`: `range(1, 6)` даёт 1, 2, 3, 4, 5.
#
# `range(start, stop, step)` добавляет шаг: `range(2, 11, 2)` даёт 2, 4, 6, 8, 10. Для движения назад нужен отрицательный шаг: `range(10, 0, -2)`.

# %%
for number in range(1, 6):
    print(number)

print("Чётные:")
for number in range(2, 11, 2):
    print(number)

# %% [markdown]
# ## 4. Пошаговое выполнение
#
# Для `range(1, 4)` Python сначала берёт 1 и выполняет тело, затем 2, затем 3. После этого числа заканчиваются и цикл завершается. Число 4 не используется. Переменная цикла на каждом шаге получает новое значение.

# %%
for number in range(1, 4):
    print("Начало, number =", number)
    print("Квадрат =", number * number)
    print("Конец")

# %% [markdown]
# ## 5. Ввод до цикла и арифметика
#
# Сначала можно получить число: `n = int(input(...))`, а затем использовать его в `range`. Для чисел от 1 до `n` обычно пишут `range(1, n + 1)`, потому что правая граница не включается. Внутри цикла разрешены обычные вычисления: сложение, вычитание, умножение, деление и остаток `%`.

# %%
n = int(input("Введите N: "))
for number in range(1, n + 1):
    print(number, "-> квадрат", number * number)

# %% [markdown]
# ## 6. `if / elif / else` внутри `for`
#
# Условие внутри цикла проверяет каждое очередное число. Чётное число можно проверить так: `number % 2 == 0`. У `if` тоже есть двоеточие и отступ; команды внутри него получают ещё один отступ.

# %%
for number in range(1, 11):
    if number % 2 == 0:
        print(number, "чётное")
    else:
        print(number, "нечётное")

# %% [markdown]
# ## 7. Накопление суммы и подсчёт
#
# Для суммы создай переменную до цикла: `summa = 0`, а внутри прибавляй: `summa = summa + number`. Для подсчёта подходящих чисел используй `count = 0` и увеличивай его на 1 внутри подходящего `if`. Не создавай накопитель внутри цикла — иначе он будет сбрасываться.

# %%
n = int(input("Введите N: "))
summa = 0
count = 0
for number in range(1, n + 1):
    summa = summa + number
    if number % 2 == 0:
        count = count + 1
print("Сумма =", summa)
print("Чётных чисел =", count)

# %% [markdown]
# ## Типичные ошибки
#
# 1. Забыто `:` после `for` или `if`.
# 2. Нет отступа у тела цикла.
# 3. Написано `range(1, n)`, хотя нужно включить `n`; используй `range(1, n + 1)`.
# 4. `input()` не превращён в число через `int()`.
# 5. Накопитель суммы создан внутри цикла.
# 6. Отрицательный шаг использован, когда начало меньше конца.
# 7. Перепутаны имена переменных.
#
# ### Вопросы для самопроверки
# 1. Сколько раз выполнится `for i in range(7)`?
# 2. Какие числа даёт `range(2, 6)`?
# 3. Почему правая граница не входит?
# 4. Что выдаёт `range(1, 10, 3)`?
# 5. Где создают `summa = 0`?
# 6. Как проверить чётность числа?

# %%
# Попробуй ответить на вопросы или провести свои эксперименты.
# Ваш код

# %% [markdown]
# # Практические задачи
#
# Решай по порядку. Используй только уже знакомые конструкции и `for`/`range`. В ячейках нет готовых решений.

# %% [markdown]
# ## Задача 1. Повторение сообщения
# Введи имя и число `N`. Выведи `Привет, имя!` ровно `N` раз.

# %%
# Ваше решение

# %% [markdown]
# ## Задача 2. Числа от 1 до N
# Пользователь вводит `N`. Выведи все числа от 1 до `N`.

# %%
# Ваше решение

# %% [markdown]
# ## Задача 3. Чётные числа
# Пользователь вводит `N`. Выведи все чётные числа от 1 до `N`, используя `if` и `%`.

# %%
# Ваше решение

# %% [markdown]
# ## Задача 4. Квадраты чисел
# Для каждого числа от 1 до `N` выведи число и его квадрат.

# %%
# Ваше решение

# %% [markdown]
# ## Задача 5. Таблица умножения
# Введи число `a` и выведи таблицу умножения для него от 1 до 10.

# %%
# Ваше решение

# %% [markdown]
# ## Задача 6. Сумма от 1 до N
# Найди сумму всех чисел от 1 до `N` через переменную-накопитель.

# %%
# Ваше решение

# %% [markdown]
# ## Задача 7. Подсчёт чисел, кратных трём
# Посчитай, сколько чисел от 1 до `N` делятся на 3 без остатка.

# %%
# Ваше решение

# %% [markdown]
# ## Задача 8. Сумма чётных чисел
# Найди сумму всех чётных чисел от 1 до `N`.

# %%
# Ваше решение

# %% [markdown]
# ## Задача 9. Сумма квадратов
# Найди сумму квадратов чисел от 1 до `N`: `1*1 + 2*2 + ... + N*N`.

# %%
# Ваше решение

# %% [markdown]
# ## Задача 10. Числа с шагом 2
# Введи `start` и `stop`. Выведи числа от `start` до числа перед `stop` с шагом 2.

# %%
# Ваше решение

# %% [markdown]
# ## Итоговая памятка
#
# `for` повторяет команды; `range(N)` идёт от 0 до `N - 1`; правая граница не включается; третий параметр задаёт шаг; тело цикла выделяется отступом; `int(input(...))` получает число; `if` проверяет каждое число; сумму и количество накапливают в переменных, созданных до цикла. Экспериментируй с примерами, меняя числа, текст, шаг и условия.
